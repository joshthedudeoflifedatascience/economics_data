# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gdp = pd.read_csv('/Users/joshthedudeoflife/Downloads/GDP.csv')

# %%
corporate_profit = pd.read_csv('/Users/joshthedudeoflife/Downloads/CP.csv')

# %%
corporate_profit.head()
# Out:
#          DATE      CP
# 0  1947-01-01  21.970
# 1  1947-04-01  20.788
# 2  1947-07-01  20.564
# 3  1947-10-01  22.451
# 4  1948-01-01  23.739

# %%
corporate_cash_on_hand = pd.read_csv('/Users/joshthedudeoflife/Downloads/QFRTCASHINFUSNO.csv')

# %%
consumer_sentiment = pd.read_csv('/Users/joshthedudeoflife/Downloads/UMCSENT.csv')

# %%
consumer_sentiment.head()
# Out:
#          DATE UMCSENT
# 0  1952-11-01    86.2
# 1  1952-12-01       .
# 2  1953-01-01       .
# 3  1953-02-01    90.7
# 4  1953-03-01       .

# %%
labor_force_participation_rate = pd.read_csv('/Users/joshthedudeoflife/Downloads/CIVPART.csv')

# %%
labor_force_participation_rate.head()
# Out:
#          DATE  CIVPART
# 0  1948-01-01     58.6
# 1  1948-02-01     58.9
# 2  1948-03-01     58.5
# 3  1948-04-01     59.0
# 4  1948-05-01     58.3

# %%
sp500 = pd.read_csv('/Users/joshthedudeoflife/Downloads/SP500.csv')

# %%
sp500.head()
# Out:
#          DATE    SP500
# 0  2012-07-30  1385.30
# 1  2012-07-31  1379.32
# 2  2012-08-01  1375.14
# 3  2012-08-02  1365.00
# 4  2012-08-03  1390.99

# %%
unemployment = pd.read_csv('/Users/joshthedudeoflife/Downloads/UNRATE.csv')

# %%
unemployment.head()
# Out:
#          DATE  UNRATE
# 0  1948-01-01     3.4
# 1  1948-02-01     3.8
# 2  1948-03-01     4.0
# 3  1948-04-01     3.9
# 4  1948-05-01     3.5

# %%
fed_funds =  pd.read_csv('/Users/joshthedudeoflife/Downloads/FEDFUNDS.csv')

# %%
fed_funds.head()
# Out:
#          DATE  FEDFUNDS
# 0  1954-07-01      0.80
# 1  1954-08-01      1.22
# 2  1954-09-01      1.07
# 3  1954-10-01      0.85
# 4  1954-11-01      0.83

# %%
recession_possibilities = pd.read_csv('/Users/joshthedudeoflife/Downloads/RECPROUSM156N.csv')

# %%
recession_possibilities.head()
# Out:
#          DATE  RECPROUSM156N
# 0  1967-06-01           1.04
# 1  1967-07-01           0.42
# 2  1967-08-01           0.02
# 3  1967-09-01           0.26
# 4  1967-10-01           0.12

# %%
drug_overdose_data = pd.read_csv('/Users/joshthedudeoflife/Downloads/VSRR_Provisional_Drug_Overdose_Death_Counts.csv')

# %%
drug_overdose_data.head()
# Out:
#   State  Year  Month           Period                     Indicator  \
# 0    AK  2015  April  12 month-ending               Cocaine (T40.5)
# 1    AK  2015  April  12 month-ending                Heroin (T40.1)
# 2    AK  2015  April  12 month-ending             Methadone (T40.3)
# 3    AK  2015  April  12 month-ending              Number of Deaths
# 4    AK  2015  April  12 month-ending  Percent with drugs specified
#
#    Data Value  Percent Complete  Percent Pending Investigation State Name  \
# 0         NaN             100.0                            0.0     Alaska
# 1         NaN             100.0                            0.0     Alaska
# 2         NaN             100.0                            0.0     Alaska
# 3       4,133             100.0                            0.0     Alaska
# 4  88.0952381             100.0                            0.0     Alaska
#
#                                             Footnote Footnote Symbol  \
# ...

# %%
gdp.head()
# Out:
#          DATE      GDP
# 0  1947-01-01  243.164
# 1  1947-04-01  245.968
# 2  1947-07-01  249.585
# 3  1947-10-01  259.745
# 4  1948-01-01  265.742

# %%
gdp['gdp_percent_change'] = gdp['GDP'].pct_change()

# %%
gdp.head()
# Out:
#          DATE      GDP  gdp_percent_change
# 0  1947-01-01  243.164                 NaN
# 1  1947-04-01  245.968            0.011531
# 2  1947-07-01  249.585            0.014705
# 3  1947-10-01  259.745            0.040708
# 4  1948-01-01  265.742            0.023088

# %%
gdp
# Out:
#            DATE        GDP  gdp_percent_change
# 0    1947-01-01    243.164                 NaN
# 1    1947-04-01    245.968            0.011531
# 2    1947-07-01    249.585            0.014705
# 3    1947-10-01    259.745            0.040708
# 4    1948-01-01    265.742            0.023088
# ..          ...        ...                 ...
# 297  2021-04-01  22740.959            0.031887
# 298  2021-07-01  23202.344            0.020289
# 299  2021-10-01  24002.815            0.034500
# 300  2022-01-01  24386.734            0.015995
# 301  2022-04-01  24851.809            0.019071
#
# [302 rows x 3 columns]

# %%
sns.lineplot(data=gdp, x="DATE", y="gdp_percent_change")
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='gdp_percent_change'>

# %%
fed_funds['fed_funds_percent_change'] = fed_funds['FEDFUNDS'].pct_change()

# %%
fed_funds.head()
# Out:
#          DATE  FEDFUNDS  fed_funds_percent_change
# 0  1954-07-01      0.80                       NaN
# 1  1954-08-01      1.22                  0.525000
# 2  1954-09-01      1.07                 -0.122951
# 3  1954-10-01      0.85                 -0.205607
# 4  1954-11-01      0.83                 -0.023529

# %%
sns.lineplot(data=fed_funds, x="DATE", y="fed_funds_percent_change")
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='fed_funds_percent_change'>

# %%
plt.style.use("ggplot")

# %%
fig, ax = plt.subplots()
sns.lineplot(data=gdp, x="DATE", y="gdp_percent_change", ax=ax)
sns.lineplot(data=fed_funds, x="DATE", y="fed_funds_percent_change", ax=ax)
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='gdp_percent_change'>

# %%
fig, ax = plt.subplots()
sns.lineplot(data=gdp, x="DATE", y="gdp_percent_change", ax=ax)
sns.lineplot(data=fed_funds, x="DATE", y="fed_funds_percent_change", ax=ax)
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='gdp_percent_change'>

# %%
sns.lineplot(data=fed_funds, x="DATE", y="fed_funds_percent_change")
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='fed_funds_percent_change'>

# %%
corporate_profit.head()
# Out:
#          DATE      CP
# 0  1947-01-01  21.970
# 1  1947-04-01  20.788
# 2  1947-07-01  20.564
# 3  1947-10-01  22.451
# 4  1948-01-01  23.739

# %%
corporate_cash_on_hand.head()
# Out:
#          DATE  QFRTCASHINFUSNO
# 0  2009-10-01            75704
# 1  2010-01-01            75101
# 2  2010-04-01            73659
# 3  2010-07-01            81497
# 4  2010-10-01            83621

# %%
consumer_sentiment.head()
# Out:
#          DATE UMCSENT
# 0  1952-11-01    86.2
# 1  1952-12-01       .
# 2  1953-01-01       .
# 3  1953-02-01    90.7
# 4  1953-03-01       .

# %%
labor_force_participation_rate.head()
# Out:
#          DATE  CIVPART
# 0  1948-01-01     58.6
# 1  1948-02-01     58.9
# 2  1948-03-01     58.5
# 3  1948-04-01     59.0
# 4  1948-05-01     58.3

# %%
fed_funds.head()
# Out:
#          DATE  FEDFUNDS  fed_funds_percent_change
# 0  1954-07-01      0.80                       NaN
# 1  1954-08-01      1.22                  0.525000
# 2  1954-09-01      1.07                 -0.122951
# 3  1954-10-01      0.85                 -0.205607
# 4  1954-11-01      0.83                 -0.023529

# %%
fed_funds
# Out:
#            DATE  FEDFUNDS  fed_funds_percent_change
# 0    1954-07-01      0.80                       NaN
# 1    1954-08-01      1.22                  0.525000
# 2    1954-09-01      1.07                 -0.122951
# 3    1954-10-01      0.85                 -0.205607
# 4    1954-11-01      0.83                 -0.023529
# ..          ...       ...                       ...
# 811  2022-02-01      0.08                  0.000000
# 812  2022-03-01      0.20                  1.500000
# 813  2022-04-01      0.33                  0.650000
# 814  2022-05-01      0.77                  1.333333
# 815  2022-06-01      1.21                  0.571429
#
# [816 rows x 3 columns]

# %%
unemployment.head()
# Out:
#          DATE  UNRATE
# 0  1948-01-01     3.4
# 1  1948-02-01     3.8
# 2  1948-03-01     4.0
# 3  1948-04-01     3.9
# 4  1948-05-01     3.5

# %%
super_df = pd.concat([fed_funds.set_index('DATE'),unemployment.set_index('DATE')], axis=1, join='inner').reset_index()

# %%
super_df.head()
# Out:
#          DATE  FEDFUNDS  fed_funds_percent_change  UNRATE
# 0  1954-07-01      0.80                       NaN     5.8
# 1  1954-08-01      1.22                  0.525000     6.0
# 2  1954-09-01      1.07                 -0.122951     6.1
# 3  1954-10-01      0.85                 -0.205607     5.7
# 4  1954-11-01      0.83                 -0.023529     5.3

# %%
sns.set(rc={'figure.figsize':(21.7,18.27)})

# %%
sns.scatterplot(data=super_df, x="DATE", y="UNRATE")
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='UNRATE'>

# %%
sns.scatterplot(data=super_df, x="DATE", y="FEDFUNDS")
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='FEDFUNDS'>

# %% [markdown]
# - The question:
#    - What do we want our output to be?
#
# - Possible target classes:
#     - Unemployment Number
#     - Change in unemployment
#     - Change in GDP
#     - Recession lasting longer than 2 quarters
#     - Double Dip recession
#     ???

# %% [markdown]
# Correlation matrix between variables:

# %% [markdown]
# 200 day moving average, when the 50 day moves below thats the death cross and when the 50 day moves above the 200 day thats the golden cross

# %% [markdown]
# -Do Linear Regression for a bad baseline (hedroskedacity amongst the variables)
# -Randomn Forest
# -Gradient Boosting (will account for variance and baised)

# %%
correlation =  gdp.merge(corporate_profit,how ='left').merge(labor_force_participation_rate,how ='left').merge(fed_funds,how ='left').merge(unemployment,how ='left').merge(consumer_sentiment,how ='left')

# %%
correlation.head()
# Out:
#          DATE      GDP  gdp_percent_change      CP  CIVPART  FEDFUNDS  \
# 0  1947-01-01  243.164                 NaN  21.970      NaN       NaN
# 1  1947-04-01  245.968            0.011531  20.788      NaN       NaN
# 2  1947-07-01  249.585            0.014705  20.564      NaN       NaN
# 3  1947-10-01  259.745            0.040708  22.451      NaN       NaN
# 4  1948-01-01  265.742            0.023088  23.739     58.6       NaN
#
#    fed_funds_percent_change  UNRATE UMCSENT
# 0                       NaN     NaN     NaN
# 1                       NaN     NaN     NaN
# 2                       NaN     NaN     NaN
# 3                       NaN     NaN     NaN
# 4                       NaN     3.4     NaN

# %% [markdown]
# # Linear Regression

# %%
correlation1 = correlation.dropna()

# %%
correlation2 = correlation1[['DATE', 'GDP', 'CP', 'CIVPART', 'FEDFUNDS', 'UNRATE']].copy()

# %%
correlation2.head()
# Out:
#           DATE      GDP      CP  CIVPART  FEDFUNDS  UNRATE
# 31  1954-10-01  399.734  25.515     58.8      0.85     5.7
# 32  1955-01-01  413.073  28.583     58.6      1.39     4.9
# 33  1955-04-01  421.532  29.064     59.0      1.43     4.7
# 34  1955-07-01  430.221  29.843     59.3      1.68     4.0
# 35  1955-10-01  437.092  31.115     59.8      2.24     4.3

# %%
corrM = correlation2.corr()
corrM
# Out:
#                GDP        CP   CIVPART  FEDFUNDS    UNRATE
# GDP       1.000000  0.968854  0.446648 -0.512710  0.044689
# CP        0.968854  1.000000  0.270301 -0.543598  0.056507
# CIVPART   0.446648  0.270301  1.000000  0.132720  0.146026
# FEDFUNDS -0.512710 -0.543598  0.132720  1.000000  0.047144
# UNRATE    0.044689  0.056507  0.146026  0.047144  1.000000

# %%
correlation2.describe()
# Out:
#                 GDP           CP     CIVPART    FEDFUNDS      UNRATE
# count    270.000000   270.000000  270.000000  270.000000  270.000000
# mean    7408.038093   611.223193   63.225926    4.640407    5.925556
# std     6789.303779   699.965059    2.834531    3.674045    1.684804
# min      399.734000    24.236000   58.500000    0.050000    3.400000
# 25%     1180.830500    67.091750   60.400000    1.752500    4.700000
# 50%     5236.435500   258.090500   63.600000    4.150000    5.650000
# 75%    12883.813500  1064.692750   66.100000    6.415000    6.975000
# max    24386.734000  2726.711000   67.300000   19.080000   14.700000

# %%
sns.pairplot(correlation2)

# %%
sns.heatmap(correlation2.corr())
# Out:
# <AxesSubplot:>

# %%
X = correlation2[['GDP', 'CP', 'CIVPART', 'FEDFUNDS']]
y = correlation2['UNRATE']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# print the intercept
print(lm.intercept_)
# Out:
# -21.181070912961243

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#           Coefficient
# GDP         -0.000645
# CP           0.005553
# CIVPART      0.452839
# FEDFUNDS    -0.042233

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 1.2043485775154823
# MSE: 3.2354599375582827
# RMSE: 1.7987384294438928

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rfc = RandomForestRegressor(n_estimators=100, max_features = 'sqrt', max_depth = 7, random_state = 18)

# %%
correlation1a = correlation.dropna()

# %%
correlation1a.head()
# Out:
#           DATE      GDP  gdp_percent_change      CP  CIVPART  FEDFUNDS  \
# 31  1954-10-01  399.734            0.022348  25.515     58.8      0.85
# 32  1955-01-01  413.073            0.033370  28.583     58.6      1.39
# 33  1955-04-01  421.532            0.020478  29.064     59.0      1.43
# 34  1955-07-01  430.221            0.020613  29.843     59.3      1.68
# 35  1955-10-01  437.092            0.015971  31.115     59.8      2.24
#
#     fed_funds_percent_change  UNRATE UMCSENT
# 31                 -0.205607     5.7       .
# 32                  0.085938     4.9       .
# 33                  0.059259     4.7       .
# 34                  0.024390     4.0       .
# 35                  0.027523     4.3       .

# %%
correlation3 = correlation1a[['GDP', 'CP', 'CIVPART', 'FEDFUNDS', 'UNRATE']].copy()

# %%
correlation3
# Out:
#            GDP        CP  CIVPART  FEDFUNDS  UNRATE
# 31     399.734    25.515     58.8      0.85     5.7
# 32     413.073    28.583     58.6      1.39     4.9
# 33     421.532    29.064     59.0      1.43     4.7
# 34     430.221    29.843     59.3      1.68     4.0
# 35     437.092    31.115     59.8      2.24     4.3
# ..         ...       ...      ...       ...     ...
# 296  22038.226  2367.593     61.4      0.09     6.4
# 297  22740.959  2690.388     61.7      0.07     6.0
# 298  23202.344  2721.601     61.7      0.10     5.4
# 299  24002.815  2700.326     61.7      0.08     4.6
# 300  24386.734  2726.711     62.2      0.08     4.0
#
# [270 rows x 5 columns]

# %%
correlation3['UNRATE'].dtype
# Out:
# dtype('float64')

# %%
correlation3.to_csv('test.csv',index=False)

# %%
X = correlation3.drop('UNRATE',axis=1)
y = correlation3['UNRATE']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=7, max_features='sqrt', random_state=18)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(rfc_pred)
# Out:
# [4.32497823 4.76968162 7.63398886 7.70126628 5.67138189 5.33721173
#  4.56538115 3.66479492 8.45391453 7.47209551 7.07171763 7.53476593
#  6.77665013 9.18093626 5.93618241 8.10713626 5.41406536 5.5374369
#  8.1213307  5.54900388 5.70482579 4.66269155 4.81269489 6.3148052
#  4.82755915 4.7523783  5.28579283 5.82797924 8.88733132 4.54924562
#  5.41489363 8.73544622 7.51519927 5.68556116 5.67233639 5.48291695
#  7.75657487 4.03265791 6.45344507 6.4863335  4.07934055 5.6438475
#  6.65723661 6.78847493 7.07598284 4.54629411 6.02280568 4.45799973
#  4.58108262 5.57995631 5.66216447 5.87795271 5.97231901 5.27405505
#  4.3067826  3.76055103 7.19230742 3.79410206 8.38034442 4.67319488
#  5.40827663 4.93975357 6.29172893 5.58841706 6.82698012 7.05961776
#  5.04268355 7.57636151 4.75664638 4.86528296 8.44791453 5.69179773
#  4.79664183 7.92523276 4.53708062 4.69103246 4.92454832 7.5658943
#  5.46727663 4.67698181 6.06498526]

# %%
mse = metrics.mean_squared_error(y_test, rfc_pred)

# %%
print(mse)
# Out:
# 0.34191746066423945

# %%
print('MAE:', metrics.mean_absolute_error(y_test, rfc_pred))
print('MSE:', metrics.mean_squared_error(y_test, rfc_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, rfc_pred)))
# Out:
# MAE: 0.4140394330332994
# MSE: 0.34191746066423945
# RMSE: 0.5847370867870786

# %% [markdown]
# # Gradiant Boost

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
correlation3.UNRATE.describe()
# Out:
# count    270.000000
# mean       5.925556
# std        1.684804
# min        3.400000
# 25%        4.700000
# 50%        5.650000
# 75%        6.975000
# max       14.700000
# Name: UNRATE, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(correlation3.drop('UNRATE',axis=1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(correlation3.drop('UNRATE',axis=1))

# %%
df_feat = pd.DataFrame(scaled_features,columns=correlation3.columns[:-1])
df_feat.head()
# Out:
#         GDP        CP   CIVPART  FEDFUNDS
# 0 -1.034174 -0.838322 -1.564331 -1.033587
# 1 -1.032205 -0.833930 -1.635020 -0.886338
# 2 -1.030957 -0.833242 -1.493642 -0.875430
# 3 -1.029675 -0.832127 -1.387607 -0.807259
# 4 -1.028661 -0.830306 -1.210884 -0.654555

# %%
X = df_feat
y = correlation3['UNRATE']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,random_state=0)

# %%
X_test = X

# %%
print(X_train.shape)
print(y_train.shape)

print(X_valid.shape)
print(y_valid.shape)

print(X_test.shape)
# Out:
# (216, 4)
# (216,)
# (54, 4)
# (54,)
# (270, 4)

# %%
# model tuning

from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import time

# A parameter grid for XGBoost
params = {
    #number of trees you want to build
    'n_estimators':[500],
    #minimum observations required at a leaf node. Larger value produces simpler trees.
    'min_child_weight':[4,5],
    #Minimum loss reduction required to make a further partition on a leaf node of the tree. 
    #The larger gamma is, the more conservative the algorithm will be.
    'gamma':[i/10.0 for i in range(3,6)],  
    'subsample':[i/10.0 for i in range(6,11)],
    'colsample_bytree':[i/10.0 for i in range(6,11)], 
    'max_depth': [2,3,4,6,7],
    'objective': ['reg:squarederror', 'reg:tweedie'],
    'booster': ['gbtree', 'gblinear'],
    'eval_metric': ['rmse'],
    'eta': [i/10.0 for i in range(3,6)],
}

reg = XGBRegressor(nthread=-1)

# run randomized search
n_iter_search = 100
random_search = RandomizedSearchCV(reg, param_distributions=params,
                                   n_iter=n_iter_search, cv=10, scoring='neg_mean_squared_error')

start = time.time()
random_search.fit(X_train, y_train)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time.time() - start), n_iter_search))
#RandomizedSearchCV took 150.07 seconds for 100 candidates parameter settings.
# Out:
# [14:07:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/learner.cc:627:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight", "subsample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [14:07:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/learner.cc:627:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight", "subsample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
# ...

# %%
best_regressor = random_search.best_estimator_

# %%
from sklearn.metrics import mean_absolute_error

# Get predictions
y_pred = best_regressor.predict(X_valid)

# %%
# Calculate MAE
rmse_pred = mean_absolute_error(y_valid, y_pred) 

print("Root Mean Absolute Error:" , np.sqrt(rmse_pred))
# Out:
# Root Mean Absolute Error: 0.7176084756859489

# %%
sns.distplot(correlation3.UNRATE)
# Out:
# /Users/joshthedudeoflife/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='UNRATE', ylabel='Density'>

# %%
X = correlation3.drop('UNRATE',axis=1)
y = correlation3['UNRATE']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,random_state=0)

# %%
X_test = X

# %%
print(X_train.shape)
print(y_train.shape)

print(X_valid.shape)
print(y_valid.shape)

print(X_test.shape)
# Out:
# (216, 4)
# (216,)
# (54, 4)
# (54,)
# (270, 4)

# %%
# model tuning

from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import time

# A parameter grid for XGBoost
params = {
    'n_estimators':[500],
    'min_child_weight':[4,5], 
    'gamma':[i/10.0 for i in range(3,6)],  
    'subsample':[i/10.0 for i in range(6,11)],
    'colsample_bytree':[i/10.0 for i in range(6,11)], 
    'max_depth': [2,3,4,6,7],
    'objective': ['reg:squarederror', 'reg:tweedie'],
    'booster': ['gbtree', 'gblinear'],
    'eval_metric': ['rmse'],
    'eta': [i/10.0 for i in range(3,6)],
}

reg = XGBRegressor(nthread=-1)

# run randomized search
n_iter_search = 100
random_search = RandomizedSearchCV(reg, param_distributions=params,
                                   n_iter=n_iter_search, cv=10, scoring='neg_mean_squared_error')

start = time.time()
random_search.fit(X_train, y_train)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time.time() - start), n_iter_search))
#RandomizedSearchCV took 150.07 seconds for 100 candidates parameter settings.
# Out:
# [13:28:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/learner.cc:627:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight", "subsample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [13:28:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/learner.cc:627:
# Parameters: { "colsample_bytree", "gamma", "max_depth", "min_child_weight", "subsample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
# ...

# %%
best_regressor = random_search.best_estimator_

# %%
from sklearn.metrics import mean_absolute_error

# Get predictions
y_pred = best_regressor.predict(X_valid)

# %%
# Calculate MAE
rmse_pred = mean_absolute_error(y_valid, y_pred) 

print("Root Mean Absolute Error:" , np.sqrt(rmse_pred))
# Out:
# Root Mean Absolute Error: 0.6748551684284517

# %%
y_pred_test = best_regressor.predict(X_test)

# %%
print(y_pred_test)
# Out:
# [ 5.8537393  4.890676   4.7202277  4.485492   4.2563133  4.1313787
#   3.8675447  4.0309844  4.144987   4.274468   4.248935   4.5717793
#   4.919515   5.16387    7.0684705  7.037985   6.547009   6.018866
#   5.2667117  5.1663256  5.115726   5.166824   5.197166   5.564534
#   6.201117   6.8134794  6.7705526  7.312051   6.1597114  5.972898
#   5.568661   5.568661   5.568661   5.568661   5.568661   5.4391804
#   5.2458253  5.2458253  5.2458253  5.1580515  5.1580515  5.107452
#   4.643423   4.643423   3.8219895  3.8219895  3.8219895  3.8219895
#   3.6752453  3.9812927  3.9812927  4.223395   4.223395   3.8219895
#   3.6126184  3.2936912  3.3641887  3.3641887  3.3969955  3.7244158
#   3.6595764  3.9955401  4.3352437  4.7499194  4.6317534  5.8165426
#   5.8165426  5.8165426  5.8165426  5.946273   5.747495   5.747495
#   5.747495   5.1180644  5.682695   4.9038143  4.9038143  4.9909034
#   4.9038143  5.6323805  6.6567755  7.7922707  8.43509    7.3679657
# ...
